# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# parameters
a, b = 3, 1
import numpy as np
p = np.linspace(beta.ppf(0.01, a, b), beta.ppf(0.99, a, b), 100)

plt.plot(beta.ppf(p, a, b))
plt.show()
