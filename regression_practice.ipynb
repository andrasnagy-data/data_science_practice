# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('import85p.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized_losses         make fuel_type aspiration  \
# 0           0          3              115.0  alfa-romero       gas        std
# 1           1          3              115.0  alfa-romero       gas        std
# 2           2          1              115.0  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  ...  bore  stroke  \
# 0          two  convertible          rwd           front  ...  3.47    2.68
# 1          two  convertible          rwd           front  ...  3.47    2.68
# 2          two    hatchback          rwd           front  ...  2.68    3.47
# 3         four        sedan          fwd           front  ...  3.19    3.40
# 4         four        sedan          4wd           front  ...  3.19    3.40
#
# ...

# %%
# visualizing realtionship between features and target (part1)
sns.pairplot(df, x_vars = ['engine_size', 'hoursepower', 'city_mpg', 'highway_mpg'],
             y_vars = ['price'], height = 7, aspect = 0.7, kind = 'reg')

# %%
# creating feature matrix and target column
feature_cols = ['engine_size', 'hoursepower', 'city_mpg', 'highway_mpg']
X = df[feature_cols]
y = df['price']

# creating linreg object
lm = LinearRegression()

from sklearn import metrics

# %%
# splitting data set to train, test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# fitting model
lm.fit(X_train, y_train)

# making predictions on test set
y_pred = lm.predict(X_test)

# calculating RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 3183.5019139244027

# %%
# range of price
print(y_test.min(), y_test.max())
# Out:
# 5348.0 37028.0

# %%
# code for iteration
# creating feature matrix and target column
feature_cols = ['engine_size', 'hoursepower', 'city_mpg']
X = df[feature_cols]
y = df['price']

# splitting data set to train, test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# fitting model
lm.fit(X_train, y_train)

# making predictions on test set
y_pred = lm.predict(X_test)

# calculating RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 3169.1605509501737

# %%
# code for iteration
# creating feature matrix and target column
feature_cols = ['engine_size', 'hoursepower']
X = df[feature_cols]
y = df['price']

# splitting data set to train, test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# fitting model
lm.fit(X_train, y_train)

# making predictions on test set
y_pred = lm.predict(X_test)

# calculating RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 3171.3679276274815

# %% [raw]
# The model with features: engine_size, hoursepower and city_mpg predicts with the lowest error.
