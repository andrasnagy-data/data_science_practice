# %%
import pandas as pd

# %%
df = pd.read_csv("import85p.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized_losses         make fuel_type aspiration  \
# 0           0          3              115.0  alfa-romero       gas        std
# 1           1          3              115.0  alfa-romero       gas        std
# 2           2          1              115.0  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  ...  bore  stroke  \
# 0          two  convertible          rwd           front  ...  3.47    2.68
# 1          two  convertible          rwd           front  ...  3.47    2.68
# 2          two    hatchback          rwd           front  ...  2.68    3.47
# 3         four        sedan          fwd           front  ...  3.19    3.40
# 4         four        sedan          4wd           front  ...  3.19    3.40
#
# ...

# %%
# relationship between drive_wheel and price
import seaborn as sns
# %matplotlib inline
sns.boxplot(x = "drive_wheels", y= "price", data = df)

# %%
# relationship between price & engine size, hoursepower
sns.pairplot(df, x_vars = ['engine_size', 'hoursepower'], y_vars = ['price'], height = 7, aspect = 0.7, kind = 'reg')

# %%
import scipy.stats as stats
# correlation coefficient for engine_size and price
pearson_coef, p_value = stats.pearsonr(df.engine_size, df.price)

# %%
print(pearson_coef, p_value)
# Out:
# 0.8887784953105816 1.252507917814005e-66
